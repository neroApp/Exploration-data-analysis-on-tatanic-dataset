# %% [markdown]
# # Table of content
# 1. Introduction of the packages
# 2. Data Importation
# 3. Data Accessing
# 4. Data Cleaning

# %%
1.#Importation of the packages
# Out:
# 1.0

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("train.csv")

# %%
2.# Data Importation

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#data accessing

# %%
#print the first five rows of the dataframe
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#print the last rows ten of the dataframe 
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# To show  random rows of the dataframe
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 23            24         1       1     Sloper, Mr. William Thompson    male
# 97            98         1       1  Greenfield, Mr. William Bertram    male
# 835          836         1       1      Compton, Miss. Sara Rebecca  female
# 158          159         0       3              Smiljanic, Mr. Mile    male
# 657          658         0       3    Bourke, Mrs. John (Catherine)  female
# 447          448         1       1      Seward, Mr. Frederic Kimber    male
# 668          669         0       3                  Cook, Mr. Jacob    male
# 215          216         1       1          Newell, Miss. Madeleine  female
# 239          240         0       2           Hunt, Mr. George Henry    male
# 131          132         0       3   Coelho, Mr. Domingos Fernandeo    male
#
#       Age  SibSp  Parch              Ticket      Fare    Cabin Embarked
# ...

# %%
# To show the summary of the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# The above dataframe consist of 12 columns and 891 rows,some of the colums having missing values

# %%
# To check the dimension of the dataframe
df.shape
# Out:
# (891, 12)

# %%
# check the datatype of the columns
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# T check the columns summary
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# check for missing values
df.isna(). sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# to check duplicate entry
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data cleaning

# %%
# we are using mean to fill the missing value because the age column is numerical
age_mean=round(df.Age.mean(),0)
df["Age"].fillna(age_mean,inplace=True)

# %%
# fill the missing cabin column with mode because it is a character variable
Cabin_mode=df.Cabin.mode()[0]
df.Cabin.fillna(Cabin_mode,inplace=True)

# %%
# Fill the missing Embarked column with mode becuase it is a text variable
Embarked_mode=df.Embarked.mode()[0]
df.Embarked.fillna(Embarked_mode,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# To extract the tittle from the name we lambda function
y =lambda x:x.split()[1].strip('.').strip(',')

# %%
df["Name"].apply(y)
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
df["Title"]=df["Name"].apply(y)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Title"]
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: object

# %%
# To find the count of the Title
df.Title.value_counts()
# Out:
# Mr             502
# Miss           179
# Mrs            121
# Master          40
# Dr               7
# Rev              6
# y                4
# Planke           3
# Impe             3
# Gordon           2
# Col              2
# Mlle             2
# Major            2
# Melkebeke        1
# Jonkheer         1
# Shawah           1
# the              1
# Velde            1
# Capt             1
# Messemaeker      1
# Carlo            1
# Ms               1
# Mme              1
# Steen            1
# Mulder           1
# Pelsmaeker       1
# Walle            1
# der              1
# Billiard         1
# Don              1
# Cruyssen         1
# Name: Title, dtype: int64

# %%
# To group the title 
all_title=["Mr","Mrs","Miss","Master","Dr","Rev"]
for Nero in df.Title:
    if Nero not in all_title:
        df.Title.replace(Nero,"others",inplace=True)

# %%
df.Title.value_counts()
# Out:
# Mr        502
# Miss      179
# Mrs       121
# Master     40
# others     36
# Dr          7
# Rev         6
# Name: Title, dtype: int64
